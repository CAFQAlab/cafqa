# %%
import sys
sys.path.append("../")
import os
import vqe_experiment as ve
import numpy as np
# Out:
#  /home/isaachyw/research/cafqa/.venv/lib/python3.12/site-packages/hypermapper/utility_functions.py:12: UserWarning:pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.

# %%
# define Hamiltonian: list of coefficients, list of Paulis, initial bitstring

# here: molecular Hamiltonian, parity mapping, two-qubit reduction
atom_string = "Li 0 0 0; H 0 0 2.0"              # PySCF atom string
num_orbitals = 3                                 # number of spatial orbitals
coeffs, paulis, HF_bitstring = ve.molecule(atom_string, new_num_orbitals=num_orbitals)

# %%
coeffs, paulis, HF_bitstring
# Out:
# (array([-5.59396305e+00,  1.61387904e+00,  3.90387222e-01,  2.52944297e-01,
#         -1.13923657e-02,  1.13923657e-02,  1.61387904e+00,  4.14787999e-01,
#         -1.72701988e-02, -2.50295510e-02,  1.72701988e-02,  2.50295510e-02,
#         -3.86183811e-02, -3.52792774e-02, -3.86183811e-02, -3.52792774e-02,
#          3.90387222e-01,  8.14827873e-02, -1.13923657e-02,  5.87484994e-03,
#          1.13923657e-02, -5.87484994e-03,  2.52944297e-01,  9.81927154e-02,
#         -3.86183811e-02, -3.86183811e-02, -1.72701988e-02,  1.72701988e-02,
#         -2.50295510e-02,  2.50295510e-02,  2.63398182e-03, -2.63398182e-03,
#         -2.63398182e-03,  2.63398182e-03,  2.65122860e-03,  2.65122860e-03,
#         -2.65122860e-03, -2.65122860e-03,  8.55526893e-04, -8.55526893e-04,
#         -6.66607492e-04,  6.66607492e-04,  6.66607492e-04, -6.66607492e-04,
#         -2.31745007e-03,  2.31745007e-03, -3.52792774e-02, -3.52792774e-02,
#          2.65122860e-03, -2.65122860e-03,  2.65122860e-03, -2.65122860e-03,
#          5.49722197e-03,  5.49722197e-03,  5.49722197e-03,  5.49722197e-03,
#         -3.05064421e-03, -3.05064421e-03, -2.42624732e-05,  2.42624732e-05,
#         -2.42624732e-05,  2.42624732e-05,  2.88459294e-04,  2.88459294e-04,
#          8.14827873e-02,  8.55526893e-04, -8.55526893e-04, -3.05064421e-03,
#         -3.05064421e-03,  1.15069387e-01, -1.40797741e-02,  1.40797741e-02,
#          5.37088735e-02,  5.87484994e-03, -5.87484994e-03, -6.66607492e-04,
#          6.66607492e-04,  6.66607492e-04, -6.66607492e-04, -2.42624732e-05,
#         -2.42624732e-05,  2.42624732e-05,  2.42624732e-05, -1.40797741e-02,
#          1.40797741e-02,  4.65515679e-03, -4.65515679e-03, -4.65515679e-03,
#          4.65515679e-03,  3.18743063e-03, -3.18743063e-03,  9.81927154e-02,
#         -2.31745007e-03,  2.31745007e-03,  2.88459294e-04,  2.88459294e-04,
#          5.37088735e-02,  3.18743063e-03, -3.18743063e-03,  8.29157930e-02,
#          7.93765816e-01]),
#  array(['IIII', 'ZIII', 'ZZII', 'IZII', 'ZXII', 'IXII', 'IIZI', 'ZIZI',
#         'IIXZ', 'ZIXZ', 'IIXI', 'ZIXI', 'IIXX', 'ZIXX', 'IIYY', 'ZIYY',
#         'IIZZ', 'ZIZZ', 'IIZX', 'ZIZX', 'IIIX', 'ZIIX', 'IIIZ', 'ZIIZ',
#         'XXII', 'YYII', 'XZII', 'XIII', 'XZZI', 'XIZI', 'XZXZ', 'XZXI',
#         'XIXZ', 'XIXI', 'XZXX', 'XZYY', 'XIXX', 'XIYY', 'XZZZ', 'XIZZ',
#         'XZZX', 'XZIX', 'XIZX', 'XIIX', 'XZIZ', 'XIIZ', 'XXZI', 'YYZI',
#         'XXXZ', 'XXXI', 'YYXZ', 'YYXI', 'XXXX', 'XXYY', 'YYXX', 'YYYY',
#         'XXZZ', 'YYZZ', 'XXZX', 'XXIX', 'YYZX', 'YYIX', 'XXIZ', 'YYIZ',
#         'ZZZI', 'ZZXZ', 'ZZXI', 'ZZXX', 'ZZYY', 'ZZZZ', 'ZZZX', 'ZZIX',
#         'ZZIZ', 'ZXZI', 'IXZI', 'ZXXZ', 'ZXXI', 'IXXZ', 'IXXI', 'ZXXX',
#         'ZXYY', 'IXXX', 'IXYY', 'ZXZZ', 'IXZZ', 'ZXZX', 'ZXIX', 'IXZX',
#         'IXIX', 'ZXIZ', 'IXIZ', 'IZZI', 'IZXZ', 'IZXI', 'IZXX', 'IZYY',
#         'IZZZ', 'IZZX', 'IZIX', 'IZIZ', 'IIII'], dtype='<U4'),
#  '1010')

# %%
# number of qubits
N = len(paulis[0])

# %%
# configure underlying VQE structure, passed as keyword argument dictionary

# a function which returns a parameterized Qiskit circuit (ansatz) and the number of parameters
ansatz_func = ve.efficientsu2_full
ansatz_reps = 1
# if True, the initial HF_bitstring will be appended after ansatz (layer of X gates where there are 1s)
# if False, HF_bitstring will be initialized before ansatz
init_last = False

vqe_kwargs = {
    "ansatz_func": ansatz_func,
    "ansatz_reps": ansatz_reps,
    "init_last": init_last,
    "HF_bitstring": HF_bitstring
}

# %%
ansatz, num_params = ansatz_func(N, ansatz_reps)
print(num_params)
# Out:
# 16

# %%
ansatz.draw(fold=-1)
# Out:
#      ┌──────────┐┌──────────┐ ░                                ░  ┌──────────┐┌───────────┐
# q_0: ┤ Ry(θ[0]) ├┤ Rz(θ[4]) ├─░───■────■────■──────────────────░──┤ Ry(θ[8]) ├┤ Rz(θ[12]) ├
#      ├──────────┤├──────────┤ ░ ┌─┴─┐  │    │                  ░  ├──────────┤├───────────┤
# q_1: ┤ Ry(θ[1]) ├┤ Rz(θ[5]) ├─░─┤ X ├──┼────┼────■────■────────░──┤ Ry(θ[9]) ├┤ Rz(θ[13]) ├
#      ├──────────┤├──────────┤ ░ └───┘┌─┴─┐  │  ┌─┴─┐  │        ░ ┌┴──────────┤├───────────┤
# q_2: ┤ Ry(θ[2]) ├┤ Rz(θ[6]) ├─░──────┤ X ├──┼──┤ X ├──┼────■───░─┤ Ry(θ[10]) ├┤ Rz(θ[14]) ├
#      ├──────────┤├──────────┤ ░      └───┘┌─┴─┐└───┘┌─┴─┐┌─┴─┐ ░ ├───────────┤├───────────┤
# q_3: ┤ Ry(θ[3]) ├┤ Rz(θ[7]) ├─░───────────┤ X ├─────┤ X ├┤ X ├─░─┤ Ry(θ[11]) ├┤ Rz(θ[15]) ├
#      └──────────┘└──────────┘ ░           └───┘     └───┘└───┘ ░ └───────────┘└───────────┘

# %% [markdown]
# CAFQA parameters are represented by a list $[x_0, x_1, x_2, ...]$ where $x_i$ parametrizes the $i$-th gate in the ansatz and can only take the discrete values $\{0,1,2,3\}$. Typically the parameterized gates are rotation gates, $R_y$ or $R_z$, so that $x_i$ corresponds to a rotation angle $x_i \cdot \pi/2$.

# %%
# configure algorithm

budget = 100                                                 # number of iterations
guess = list(map(int, np.random.randint(0, 4, num_params)))  # initial param guess
guess
# Out:
# [0, 1, 2, 3, 0, 3, 0, 2, 3, 1, 0, 3, 0, 3, 2, 3]

# %%
# get VQE circuit guess parameters (* pi/2)
qc = ve.vqe_circuit(
    N, 
    np.array(guess)*np.pi/2, 
    paulis, 
    ansatz_func=ansatz_func, 
    ansatz_reps=ansatz_reps, 
    init_last=init_last,
    HF_bitstring=HF_bitstring
    )

# %%
qc.draw(fold=-1)
# Out:
#          ┌───┐     ┌───────┐  ┌───────┐ ░                                ░ ┌──────────┐ ┌───────┐
# q1_0: ───┤ X ├─────┤ Ry(0) ├──┤ Rz(0) ├─░───■────■────■──────────────────░─┤ Ry(3π/2) ├─┤ Rz(0) ├──
#       ┌──┴───┴──┐ ┌┴───────┴─┐└───────┘ ░ ┌─┴─┐  │    │                  ░ ├─────────┬┘┌┴───────┴─┐
# q1_1: ┤ Ry(π/2) ├─┤ Rz(3π/2) ├──────────░─┤ X ├──┼────┼────■────■────────░─┤ Ry(π/2) ├─┤ Rz(3π/2) ├
#       └──┬───┬──┘ └┬───────┬─┘┌───────┐ ░ └───┘┌─┴─┐  │  ┌─┴─┐  │        ░ └┬───────┬┘ └┬───────┬─┘
# q1_2: ───┤ X ├─────┤ Ry(π) ├──┤ Rz(0) ├─░──────┤ X ├──┼──┤ X ├──┼────■───░──┤ Ry(0) ├───┤ Rz(π) ├──
#       ┌──┴───┴───┐ ├───────┤  └───────┘ ░      └───┘┌─┴─┐└───┘┌─┴─┐┌─┴─┐ ░ ┌┴───────┴─┐┌┴───────┴─┐
# q1_3: ┤ Ry(3π/2) ├─┤ Rz(π) ├────────────░───────────┤ X ├─────┤ X ├┤ X ├─░─┤ Ry(3π/2) ├┤ Rz(3π/2) ├
#       └──────────┘ └───────┘            ░           └───┘     └───┘└───┘ ░ └──────────┘└──────────┘
# c0: 4/═════════════════════════════════════════════════════════════════════════════════════════════

# %%
# configure output

save_dir = "cafqa_example_out/"
os.system(f"mkdir -p {save_dir}")
# the output files are relative to save_dir
result_file = "result.txt"
loss_file = "cafqa_loss.txt"
params_file = "cafqa_params.txt"

# %%
# run CAFQA

# hypermapper changes the standard output to write to log files, so it needs to be
# changed back after CAFQA (otherwise printing breaks)
stdout = sys.stdout
cafqa_energy, cafqa_params = ve.run_cafqa(
    n_qubits=N,
    coeffs=coeffs,
    paulis=paulis,
    param_guess=list(guess),
    budget=budget,
    save_dir=save_dir,
    loss_file=loss_file,
    params_file=params_file,
    vqe_kwargs=vqe_kwargs
)
sys.stdout = stdout
# Out:
# Design of experiment phase, number of new doe samples = 100 .......
# Loss computed by CAFQA VQE is -4.527665285199616, in 0.017038018442690372 s.
# Loss computed by CAFQA VQE is -4.7756689493024425, in 0.015462230890989304 s.
# Loss computed by CAFQA VQE is -7.459014456414215, in 0.015412271954119205 s.
# Loss computed by CAFQA VQE is -4.349342238016441, in 0.015174859203398228 s.
# Loss computed by CAFQA VQE is -3.5374552045456764, in 0.014691059477627277 s.
# Loss computed by CAFQA VQE is -4.7833051804355655, in 0.015155164524912834 s.
# Loss computed by CAFQA VQE is -4.830181989844099, in 0.015800582244992256 s.
# Loss computed by CAFQA VQE is -3.0756382996902847, in 0.015141119249165058 s.
# Loss computed by CAFQA VQE is -3.349583835599441, in 0.015435229055583477 s.
# Loss computed by CAFQA VQE is -5.085394912370914, in 0.015374667942523956 s.
# Loss computed by CAFQA VQE is -7.767320163607325, in 0.013581061735749245 s.
# Loss computed by CAFQA VQE is -4.723744571344313, in 0.015667103230953217 s.
# Loss computed by CAFQA VQE is -4.785927693545842, in 0.01527463924139738 s.
# Loss computed by CAFQA VQE is -6.265701015342524, in 0.013045718893408775 s.
# Loss computed by CAFQA VQE is -4.849422447027979, in 0.015449943952262402 s.
# Loss computed by CAFQA VQE is -4.350700760006154, in 0.016890441067516804 s.
# Loss computed by CAFQA VQE is -3.6581882019814485, in 0.013979649171233177 s.
# Loss computed by CAFQA VQE is -4.895714455384089, in 0.015034817159175873 s.
# Loss computed by CAFQA VQE is -4.772946953217621, in 0.015315341763198376 s.
# Loss computed by CAFQA VQE is -4.103156838105281, in 0.01705106906592846 s.
# Loss computed by CAFQA VQE is -5.312006196284209, in 0.012917427346110344 s.
# Loss computed by CAFQA VQE is -4.808896795134118, in 0.013377503491938114 s.
# Loss computed by CAFQA VQE is -6.417415373679287, in 0.014924293383955956 s.
# Loss computed by CAFQA VQE is -6.406316917817433, in 0.015398446470499039 s.
# Loss computed by CAFQA VQE is -5.241590507722142, in 0.1994017045944929 s.
# Loss computed by CAFQA VQE is -5.081460163717108, in 0.014375079423189163 s.
# Loss computed by CAFQA VQE is -5.092949626930315, in 0.014275368303060532 s.
# Loss computed by CAFQA VQE is -5.103594937036327, in 0.015066093765199184 s.
# Loss computed by CAFQA VQE is -4.508923012323802, in 0.014055905863642693 s.
# Loss computed by CAFQA VQE is -4.738833217054187, in 0.01594120543450117 s.
# Loss computed by CAFQA VQE is -3.187780115372549, in 0.013493717648088932 s.
# Loss computed by CAFQA VQE is -3.144018442373534, in 0.014141224324703217 s.
# Loss computed by CAFQA VQE is -4.652860696929252, in 0.013222651556134224 s.
# Loss computed by CAFQA VQE is -6.41095181794744, in 0.016225597821176052 s.
# Loss computed by CAFQA VQE is -4.808438345997132, in 0.013957983814179897 s.
# Loss computed by CAFQA VQE is -4.566840583014952, in 0.014041510410606861 s.
# Loss computed by CAFQA VQE is -6.4313434855838985, in 0.01401625107973814 s.
# Loss computed by CAFQA VQE is -3.228617942027161, in 0.013693273067474365 s.
# Loss computed by CAFQA VQE is -4.103156838105281, in 0.01628422550857067 s.
# Loss computed by CAFQA VQE is -4.766598704405826, in 0.014902858063578606 s.
# Loss computed by CAFQA VQE is -4.803697383473948, in 0.015114475972950459 s.
# Loss computed by CAFQA VQE is -1.9023384028501438, in 0.015383557416498661 s.
# Loss computed by CAFQA VQE is -4.877944764041424, in 0.016136000864207745 s.
# Loss computed by CAFQA VQE is -4.688067064411669, in 0.0145720224827528 s.
# Loss computed by CAFQA VQE is -6.551519195261292, in 0.01393885724246502 s.
# Loss computed by CAFQA VQE is -4.708909922733217, in 0.014710258692502975 s.
# Loss computed by CAFQA VQE is -4.750835845029313, in 0.015455867163836956 s.
# Loss computed by CAFQA VQE is -3.1808006764472028, in 0.015369498170912266 s.
# Loss computed by CAFQA VQE is -4.497540287834063, in 0.014491906389594078 s.
# Loss computed by CAFQA VQE is -4.892226116991589, in 0.015157700516283512 s.
# Loss computed by CAFQA VQE is -4.853434582404846, in 0.012998874299228191 s.
# Loss computed by CAFQA VQE is -4.981365963889493, in 0.013001921586692333 s.
# Loss computed by CAFQA VQE is -4.837818220977222, in 0.015965216793119907 s.
# Loss computed by CAFQA VQE is -5.121286308918926, in 0.014339054934680462 s.
# Loss computed by CAFQA VQE is -5.028967503961574, in 0.014429854229092598 s.
# Loss computed by CAFQA VQE is -4.818094500324776, in 0.014417770318686962 s.
# Loss computed by CAFQA VQE is -6.306913642955587, in 0.015936175361275673 s.
# Loss computed by CAFQA VQE is -4.767259666260257, in 0.015214554034173489 s.
# Loss computed by CAFQA VQE is -6.265701015342524, in 0.014102690853178501 s.
# Loss computed by CAFQA VQE is -5.1160836248096455, in 0.01374819129705429 s.
# Loss computed by CAFQA VQE is -3.1808006764472037, in 0.015276418998837471 s.
# Loss computed by CAFQA VQE is -6.25932468835955, in 0.014785789884626865 s.
# Loss computed by CAFQA VQE is -4.598442622080285, in 0.015856003388762474 s.
# Loss computed by CAFQA VQE is -4.8028312128990915, in 0.014988132752478123 s.
# Loss computed by CAFQA VQE is -3.26021585063674, in 0.014836188405752182 s.
# Loss computed by CAFQA VQE is -3.183634942626947, in 0.012520130723714828 s.
# Loss computed by CAFQA VQE is -4.426224680540042, in 0.016179731115698814 s.
# Loss computed by CAFQA VQE is -5.014234687680583, in 0.012910425662994385 s.
# Loss computed by CAFQA VQE is -3.355096452307647, in 0.01309333834797144 s.
# Loss computed by CAFQA VQE is -3.1918357079534907, in 0.014145282097160816 s.
# Loss computed by CAFQA VQE is -6.402178006558458, in 0.013294822536408901 s.
# Loss computed by CAFQA VQE is -5.22557527163314, in 0.017119805328547955 s.
# Loss computed by CAFQA VQE is -5.208710179304552, in 0.014809655956923962 s.
# Loss computed by CAFQA VQE is -5.138463196567025, in 0.016140020452439785 s.
# Loss computed by CAFQA VQE is -6.488090980430172, in 0.012376880273222923 s.
# Loss computed by CAFQA VQE is -3.1918357079534903, in 0.016362106427550316 s.
# Loss computed by CAFQA VQE is -2.835181179855018, in 0.01387589517980814 s.
# Loss computed by CAFQA VQE is -4.847885261563462, in 0.013460082933306694 s.
# Loss computed by CAFQA VQE is -4.331731701691147, in 0.014977183192968369 s.
# Loss computed by CAFQA VQE is -4.805694453049041, in 0.014875072054564953 s.
# Loss computed by CAFQA VQE is -4.566840583014952, in 0.016574797220528126 s.
# Loss computed by CAFQA VQE is -5.038561731738076, in 0.013322546146810055 s.
# Loss computed by CAFQA VQE is -4.217769171118874, in 0.01517849788069725 s.
# Loss computed by CAFQA VQE is -4.74526887428323, in 0.013754721730947495 s.
# Loss computed by CAFQA VQE is -6.396809054335819, in 0.013238482177257538 s.
# Loss computed by CAFQA VQE is -4.8255582250906155, in 0.015717563219368458 s.
# Loss computed by CAFQA VQE is -5.175259006248815, in 0.014985664747655392 s.
# Loss computed by CAFQA VQE is -4.426224680540042, in 0.01549112144857645 s.
# Loss computed by CAFQA VQE is -6.421835622102284, in 0.014654881320893764 s.
# Loss computed by CAFQA VQE is -2.0552249938816316, in 0.01279174443334341 s.
# Loss computed by CAFQA VQE is -4.895762980330415, in 0.017429332248866558 s.
# Loss computed by CAFQA VQE is -3.2478615839521465, in 0.014171959832310677 s.
# Loss computed by CAFQA VQE is -4.733660167210308, in 0.013476550579071045 s.
# Loss computed by CAFQA VQE is -5.9063683961655675, in 0.01348456833511591 s.
# Loss computed by CAFQA VQE is -6.4003841057092705, in 0.01430671475827694 s.
# Loss computed by CAFQA VQE is -4.83223512030571, in 0.015122368931770325 s.
# Loss computed by CAFQA VQE is -6.259709460380049, in 0.01120788510888815 s.
# Loss computed by CAFQA VQE is -4.874906255548922, in 0.014030041173100471 s.
# Loss computed by CAFQA VQE is -5.088061342339254, in 0.0146042974665761 s.
# Loss computed by CAFQA VQE is -5.110611758016886, in 0.015168986283242702 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,1,2,3,0,3,0,2,3,1,0,3,0,3,2,3,-4.527665285199616,53
# 1,1,3,1,2,2,1,0,2,3,2,0,1,1,0,0,-4.7756689493024425,71
# 0,2,2,0,3,0,3,3,0,2,0,3,2,0,2,1,-7.459014456414215,90
# 1,1,3,0,2,1,2,0,3,3,0,3,3,2,0,1,-4.349342238016441,108
# 0,1,0,2,3,3,3,3,2,3,0,2,3,3,2,2,-3.5374552045456764,125
# 2,3,3,2,0,1,2,0,3,1,0,1,2,1,1,3,-4.7833051804355655,143
# 3,3,0,1,3,2,0,2,0,3,2,2,1,2,3,0,-4.830181989844099,161
# 3,2,3,1,1,0,2,0,3,3,1,2,1,1,0,2,-3.0756382996902847,179
# 2,1,1,2,3,2,3,2,0,1,1,1,3,0,2,1,-3.349583835599441,197
# 1,1,3,3,3,3,3,0,1,2,3,3,0,0,2,1,-5.085394912370914,215
# 2,2,0,1,0,3,3,1,2,2,2,0,0,2,1,2,-7.767320163607325,232
# 2,3,0,3,3,0,2,3,3,3,2,3,2,0,0,1,-4.723744571344313,251
# 2,1,1,2,1,2,2,3,3,2,0,1,2,1,1,0,-4.785927693545842,269
# 0,0,0,2,2,2,3,0,0,0,3,3,0,1,2,3,-6.265701015342524,285
# 3,3,2,3,1,2,2,0,2,2,1,0,3,2,3,3,-4.849422447027979,304
# 3,1,2,3,3,1,0,2,2,0,2,3,2,3,0,1,-4.350700760006154,324
# 2,1,3,2,2,0,0,2,0,0,3,1,3,3,1,0,-3.6581882019814485,341
# 1,1,3,2,3,0,0,3,2,1,3,2,2,0,3,3,-4.895714455384089,359
# 1,0,2,3,1,2,2,3,2,3,3,1,0,1,3,1,-4.772946953217621,378
# 3,1,0,1,2,2,1,2,1,3,2,1,2,3,3,2,-4.103156838105281,399
# 2,0,3,0,0,0,1,2,3,2,2,0,1,2,1,0,-5.312006196284209,415
# 3,0,2,0,0,3,0,2,2,1,3,1,0,0,1,3,-4.808896795134118,431
# 2,0,3,3,1,3,2,1,2,3,0,2,1,1,2,2,-6.417415373679287,449
# 2,0,2,1,3,1,1,1,1,3,2,0,2,1,2,2,-6.406316917817433,468
# 1,0,3,3,1,2,1,0,2,0,2,2,1,3,3,2,-5.241590507722142,671
# 1,1,2,0,2,2,3,3,2,2,0,2,3,0,3,0,-5.081460163717108,688
# 3,2,1,1,2,2,0,1,3,3,3,0,0,0,3,0,-5.092949626930315,706
# 2,2,2,1,1,2,1,1,1,0,1,1,2,0,3,1,-5.103594937036327,724
# 1,2,0,0,2,3,2,2,3,0,3,2,1,3,2,0,-4.508923012323802,741
# 1,1,0,3,3,1,3,1,1,3,0,0,1,3,2,0,-4.738833217054187,760
# 0,1,0,1,0,3,1,3,2,3,3,0,1,0,1,0,-3.187780115372549,777
# 3,0,2,1,3,1,0,3,2,1,0,0,1,3,1,1,-3.144018442373534,794
# 1,1,3,0,0,1,3,3,2,0,0,2,0,1,1,0,-4.652860696929252,810
# 2,1,2,2,1,0,1,2,2,0,3,3,3,1,2,1,-6.41095181794744,829
# 3,3,1,0,0,0,2,0,0,3,2,2,3,2,1,2,-4.808438345997132,846
# 0,2,0,1,0,0,3,2,3,1,1,1,2,1,0,3,-4.566840583014952,863
# 0,0,3,3,2,2,3,1,0,3,0,3,2,1,0,1,-6.4313434855838985,880
# 2,2,3,2,2,3,1,3,0,1,1,0,0,1,0,0,-3.228617942027161,897
# 3,2,2,2,1,2,0,1,2,0,1,2,2,3,0,1,-4.103156838105281,916
# 0,1,1,2,2,3,1,3,1,3,2,3,0,3,0,0,-4.766598704405826,934
# 1,1,3,0,1,3,0,3,2,1,2,3,0,1,1,2,-4.803697383473948,952
# 2,2,3,1,1,1,2,3,0,2,1,3,0,1,1,2,-1.9023384028501438,971
# 1,1,0,2,0,3,1,3,3,0,3,1,0,2,3,2,-4.877944764041424,990
# 2,3,2,1,0,2,3,0,1,0,0,2,3,3,1,2,-4.688067064411669,1008
# 0,0,1,1,2,3,0,3,0,2,3,2,1,2,0,1,-6.551519195261292,1025
# 1,0,3,3,3,0,1,3,3,0,0,2,3,2,2,3,-4.708909922733217,1043
# 3,2,1,3,1,1,3,1,0,1,0,3,1,0,3,2,-4.750835845029313,1062
# 2,1,0,2,1,3,3,3,0,1,0,1,1,2,2,0,-3.1808006764472028,1080
# 3,1,0,3,1,2,0,0,2,3,2,1,1,0,1,1,-4.497540287834063,1098
# 3,3,1,1,0,2,1,0,2,1,3,2,1,1,0,3,-4.892226116991589,1117
# 1,0,1,0,3,3,1,0,1,0,2,1,0,0,0,3,-4.853434582404846,1133
# 0,0,3,3,0,2,1,2,3,0,1,0,0,2,1,0,-4.981365963889493,1149
# 1,3,0,1,1,1,2,0,2,1,0,2,0,1,3,3,-4.837818220977222,1168
# 0,2,2,0,3,0,3,0,3,2,1,1,2,3,1,3,-5.121286308918926,1186
# 1,1,1,3,0,0,3,0,2,2,3,3,0,3,1,0,-5.028967503961574,1203
# 3,1,1,2,2,1,0,3,0,2,1,0,2,3,1,0,-4.818094500324776,1221
# 3,1,3,3,0,3,2,0,0,3,1,3,0,1,1,0,-6.306913642955587,1240
# 0,3,3,3,3,0,3,2,1,2,2,2,3,2,3,3,-4.767259666260257,1258
# 0,1,1,3,1,0,0,2,0,3,2,2,0,1,2,1,-6.265701015342524,1275
# 1,0,1,2,0,0,2,1,3,3,0,1,2,0,3,0,-5.1160836248096455,1292
# 3,2,0,3,3,3,1,1,3,2,0,3,3,1,1,3,-3.1808006764472037,1311
# 0,0,0,2,2,1,2,1,0,1,3,0,1,1,2,2,-6.25932468835955,1328
# 1,1,1,3,2,0,1,1,3,3,1,0,1,1,3,3,-4.598442622080285,1347
# 3,0,2,2,1,3,2,0,0,1,3,1,1,3,2,3,-4.8028312128990915,1365
# 1,0,2,1,2,1,0,3,1,0,0,3,3,1,2,3,-3.26021585063674,1383
# 0,3,0,2,3,0,0,2,2,2,0,0,3,0,2,3,-3.183634942626947,1399
# 3,2,1,2,0,3,0,2,2,1,3,1,0,1,1,2,-4.426224680540042,1418
# 3,0,0,0,0,2,2,2,1,0,3,0,1,1,3,0,-5.014234687680583,1434
# 2,1,1,0,3,2,2,3,0,2,0,0,0,0,2,1,-3.355096452307647,1451
# 0,2,2,0,1,1,0,2,2,3,3,1,2,0,3,2,-3.1918357079534907,1468
# 0,2,2,0,0,3,1,1,3,2,0,2,3,3,0,1,-6.402178006558458,1484
# 1,3,1,1,0,3,0,3,3,2,1,1,2,3,1,1,-5.22557527163314,1504
# 1,2,1,2,0,3,3,2,1,2,2,0,0,1,2,2,-5.208710179304552,1522
# 3,3,3,1,3,2,3,2,3,1,3,3,3,0,3,0,-5.138463196567025,1541
# 0,1,0,0,2,0,1,0,0,1,1,0,2,2,0,2,-6.488090980430172,1557
# 2,1,0,3,2,1,2,3,0,2,1,1,3,2,1,3,-3.1918357079534903,1576
# 0,1,3,3,0,0,2,0,2,0,2,1,3,1,2,1,-2.835181179855018,1593
# 0,3,0,2,0,2,3,3,3,2,0,1,0,3,2,0,-4.847885261563462,1610
# 1,1,3,0,2,1,2,2,3,3,2,0,2,0,1,3,-4.331731701691147,1628
# 0,0,3,0,1,2,2,3,1,3,1,2,1,1,3,3,-4.805694453049041,1646
# 0,2,2,3,2,3,1,2,1,3,1,3,0,3,0,1,-4.566840583014952,1665
# 0,0,0,1,0,2,0,1,3,0,3,2,3,2,3,1,-5.038561731738076,1682
# 1,3,3,1,1,0,1,1,1,3,1,0,1,0,2,0,-4.217769171118874,1700
# 1,1,1,2,1,3,3,1,0,2,0,0,3,0,0,1,-4.74526887428323,1717
# 0,0,1,2,0,0,3,1,0,1,1,2,0,1,3,1,-6.396809054335819,1733
# 1,0,2,2,0,2,2,0,2,1,1,1,3,2,0,2,-4.8255582250906155,1752
# 3,3,3,0,1,0,2,2,3,3,1,1,2,1,0,0,-5.175259006248815,1770
# 3,2,2,2,2,2,3,3,2,0,3,1,3,1,2,1,-4.426224680540042,1789
# 1,0,3,3,3,1,2,0,1,2,1,0,0,2,2,3,-6.421835622102284,1806
# 2,2,2,0,2,0,1,0,0,2,3,0,3,1,0,2,-2.0552249938816316,1823
# 1,3,2,1,2,0,3,1,2,3,3,3,1,2,3,2,-4.895762980330415,1843
# 0,1,1,0,3,3,3,1,2,0,2,3,0,2,3,0,-3.2478615839521465,1860
# 1,1,1,3,1,0,2,1,0,0,0,1,0,1,0,0,-4.733660167210308,1877
# 1,0,2,3,3,3,2,0,0,0,2,3,0,3,1,0,-5.9063683961655675,1894
# 1,2,0,0,1,3,1,1,3,2,2,1,0,2,0,2,-6.4003841057092705,1911
# 1,3,3,2,0,1,3,0,0,0,3,2,0,2,3,2,-4.83223512030571,1929
# 0,0,1,2,2,0,2,0,0,0,1,0,0,1,0,0,-6.259709460380049,1944
# 3,3,3,3,0,3,2,0,0,0,0,2,2,3,2,2,-4.874906255548922,1961
# 1,1,0,3,1,1,0,0,3,0,3,3,3,1,2,0,-5.088061342339254,1978
# 0,2,3,1,3,2,0,3,1,3,3,1,3,0,2,1,-5.110611758016886,1997
#
#
# End of doe/resume phase, the number of evaluated configurations is: 100
#
# Starting optimization iteration 1
# Loss computed by CAFQA VQE is -4.350700760220883, in 0.01531854085624218 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 1,1,0,0,0,3,3,1,0,2,0,2,0,1,0,0,-4.350700760220883,4297
#
# Starting optimization iteration 2
# Loss computed by CAFQA VQE is -6.615083053625845, in 0.015283032320439816 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 2,1,0,0,0,3,0,0,2,2,3,0,0,1,0,2,-6.615083053625845,6444
#
# Starting optimization iteration 3
# Loss computed by CAFQA VQE is -5.146884105356685, in 0.016675676219165325 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 2,2,0,0,1,3,3,0,3,3,3,0,0,2,0,2,-5.146884105356685,8510
#
# Starting optimization iteration 4
# Loss computed by CAFQA VQE is -6.5714942815285085, in 0.013690675608813763 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,1,2,2,0,2,3,0,0,2,1,0,0,3,1,2,-6.5714942815285085,8588
#
# Starting optimization iteration 5
# Loss computed by CAFQA VQE is -3.5483524471030057, in 0.015810756012797356 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 2,3,0,0,0,2,3,0,0,2,2,0,0,3,2,2,-3.5483524471030057,10690
#
# Starting optimization iteration 6
# Loss computed by CAFQA VQE is -3.824274883902901, in 0.016802041791379452 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,2,2,1,0,3,3,0,2,2,1,0,0,0,1,2,-3.824274883902901,12761
#
# Starting optimization iteration 7
# Loss computed by CAFQA VQE is -4.728227871323454, in 0.01707108411937952 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 1,1,0,1,1,3,3,1,0,2,1,0,0,3,1,2,-4.728227871323454,14826
#
# Starting optimization iteration 8
# Loss computed by CAFQA VQE is -4.751329213111772, in 0.0164688965305686 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 2,2,0,1,0,3,3,1,0,2,2,2,0,2,1,2,-4.751329213111772,16910
#
# Starting optimization iteration 9
# Loss computed by CAFQA VQE is -6.4307862088993915, in 0.015532451681792736 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,3,0,0,2,0,0,3,0,2,0,3,0,0,1,2,-6.4307862088993915,19062
#
# Starting optimization iteration 10
# Loss computed by CAFQA VQE is -6.575173805477657, in 0.01623601745814085 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 2,1,0,0,0,3,0,0,2,2,3,0,0,2,0,2,-6.575173805477657,21171
#
# Starting optimization iteration 11
# Loss computed by CAFQA VQE is -3.34958383559944, in 0.016564070247113705 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 2,3,2,0,1,0,2,3,0,2,0,3,1,3,1,2,-3.34958383559944,23306
#
# Starting optimization iteration 12
# Loss computed by CAFQA VQE is -6.363359285235472, in 0.017097868025302887 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,3,1,0,2,1,3,3,0,1,0,3,2,0,3,0,-6.363359285235472,25401
#
# Starting optimization iteration 13
# Loss computed by CAFQA VQE is -6.2146741033586785, in 0.016761330887675285 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,3,2,2,3,0,3,3,0,3,3,2,0,2,0,0,-6.2146741033586785,27514
#
# Starting optimization iteration 14
# Loss computed by CAFQA VQE is -5.335718227344721, in 0.01587679050862789 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 2,2,0,1,0,3,3,1,2,2,0,0,0,2,1,2,-5.335718227344721,29652
#
# Starting optimization iteration 15
# Loss computed by CAFQA VQE is -7.5280832971920955, in 0.017301086336374283 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,2,2,0,2,1,1,3,0,1,0,2,2,2,0,2,-7.5280832971920955,31831
#
# Starting optimization iteration 16
# Loss computed by CAFQA VQE is -6.105171834762994, in 0.015621636062860489 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,2,3,0,3,2,0,3,0,1,0,2,2,3,0,2,-6.105171834762994,33992
#
# Starting optimization iteration 17
# Loss computed by CAFQA VQE is -6.556105560015294, in 0.016478546895086765 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,2,1,0,3,1,3,1,0,0,0,3,2,0,3,2,-6.556105560015294,36110
#
# Starting optimization iteration 18
# Loss computed by CAFQA VQE is -4.784146550657027, in 0.01515127532184124 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 3,2,3,2,1,0,1,0,3,0,3,1,0,3,2,1,-4.784146550657027,36214
#
# Starting optimization iteration 19
# Loss computed by CAFQA VQE is -7.767320163607326, in 0.015015941113233566 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,2,2,0,2,0,1,3,0,1,0,0,2,1,1,0,-7.767320163607326,38378
#
# Starting optimization iteration 20
# Loss computed by CAFQA VQE is -7.5280832971920955, in 0.0195290120318532 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,2,2,0,2,1,1,3,0,1,0,2,3,2,0,2,-7.5280832971920955,40430
#
# Starting optimization iteration 21
# Loss computed by CAFQA VQE is -6.25932468835955, in 0.01582551933825016 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,3,2,0,2,0,3,3,0,1,0,0,3,1,0,0,-6.25932468835955,42531
#
# Starting optimization iteration 22
# Loss computed by CAFQA VQE is -6.432167948829887, in 0.017892873845994473 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,1,3,0,2,0,1,3,0,3,1,1,3,1,0,1,-6.432167948829887,44715
#
# Starting optimization iteration 23
# Loss computed by CAFQA VQE is -6.416082158480384, in 0.01635506097227335 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,1,2,0,2,3,1,3,0,3,0,1,2,1,0,1,-6.416082158480384,46865
#
# Starting optimization iteration 24
# Loss computed by CAFQA VQE is -6.6335418782735776, in 0.016855990514159203 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,2,1,2,2,1,2,3,0,2,0,2,2,2,1,1,-6.6335418782735776,49055
#
# Starting optimization iteration 25
# Loss computed by CAFQA VQE is -7.57863287876269, in 0.0170156117528677 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,2,2,1,2,0,1,2,0,1,0,2,3,1,1,0,-7.57863287876269,51170
#
# Starting optimization iteration 26
# Loss computed by CAFQA VQE is -7.767320141889044, in 0.014759174548089504 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,2,2,2,2,0,1,2,0,0,0,3,0,2,2,0,-7.767320141889044,53244
#
# Starting optimization iteration 27
# Loss computed by CAFQA VQE is -7.767320163607326, in 0.014946055598556995 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,2,2,0,2,0,1,3,0,1,0,0,3,1,1,0,-7.767320163607326,55362
#
# Starting optimization iteration 28
# Loss computed by CAFQA VQE is -7.703734742577579, in 0.015796087682247162 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,2,2,2,1,0,1,3,0,0,0,0,0,2,2,0,-7.703734742577579,57582
#
# Starting optimization iteration 29
# Loss computed by CAFQA VQE is -7.703734742577578, in 0.014897726476192474 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,2,2,0,0,0,1,3,0,2,0,0,1,3,1,3,-7.703734742577578,59767
#
# Starting optimization iteration 30
# Loss computed by CAFQA VQE is -7.830905584637071, in 0.015394368208944798 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,2,2,0,2,0,1,3,0,0,0,0,3,2,2,3,-7.830905584637071,61980
#
# Starting optimization iteration 31
# Loss computed by CAFQA VQE is -6.556105570659704, in 0.015980816446244717 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,2,3,1,2,0,1,3,0,0,0,1,2,3,1,0,-6.556105570659704,64155
#
# Starting optimization iteration 32
# Loss computed by CAFQA VQE is -7.703734742577579, in 0.028934900648891926 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,2,2,2,1,1,1,3,0,0,0,0,0,2,0,2,-7.703734742577579,66280
#
# Starting optimization iteration 33
# Loss computed by CAFQA VQE is -6.367560694390168, in 0.015769334509968758 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,2,2,0,2,0,1,3,0,0,3,0,3,2,0,3,-6.367560694390168,68524
#
# Starting optimization iteration 34
# Loss computed by CAFQA VQE is -4.824395517644614, in 0.015142915770411491 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 1,3,2,3,2,3,3,3,0,2,3,0,1,2,2,0,-4.824395517644614,68613
#
# Starting optimization iteration 35
# Loss computed by CAFQA VQE is -7.830905584637071, in 0.014144192449748516 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,2,2,0,3,0,0,2,0,0,0,0,2,2,2,3,-7.830905584637071,70808
#
# Starting optimization iteration 36
# Loss computed by CAFQA VQE is -7.528083297192095, in 0.016185506246984005 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,2,2,0,1,1,0,2,0,2,0,3,0,0,3,0,-7.528083297192095,73032
#
# Starting optimization iteration 37
# Loss computed by CAFQA VQE is -6.417200721972279, in 0.016750898212194443 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 2,1,0,1,3,3,3,1,2,2,3,0,0,2,0,2,-6.417200721972279,75215
#
# Starting optimization iteration 38
# Loss computed by CAFQA VQE is -4.850232240319768, in 0.014713797718286514 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 3,0,3,1,3,0,0,3,1,2,2,1,3,0,3,3,-4.850232240319768,75325
#
# Starting optimization iteration 39
# Loss computed by CAFQA VQE is -7.703734742577579, in 0.0236879400908947 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,2,2,2,2,0,0,2,0,0,0,0,3,0,1,3,-7.703734742577579,77490
#
# Starting optimization iteration 40
# Loss computed by CAFQA VQE is -7.767320163607325, in 0.015203763730823994 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,2,2,1,2,0,1,3,0,0,0,0,0,0,2,0,-7.767320163607325,79672
#
# Starting optimization iteration 41
# Loss computed by CAFQA VQE is -6.799063117591624, in 0.014068578369915485 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,2,1,0,3,0,0,2,0,0,0,0,3,2,3,0,-6.799063117591624,81883
#
# Starting optimization iteration 42
# Loss computed by CAFQA VQE is -6.214674103358679, in 0.016016962006688118 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,1,2,0,2,1,1,3,0,0,0,0,3,2,2,2,-6.214674103358679,84079
#
# Starting optimization iteration 43
# Loss computed by CAFQA VQE is -6.5515191846168825, in 0.016200958751142025 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,2,2,0,3,1,0,3,0,0,1,1,2,2,3,0,-6.5515191846168825,86510
#
# Starting optimization iteration 44
# Loss computed by CAFQA VQE is -7.830905584637071, in 0.027646658942103386 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,2,2,0,1,0,2,2,0,0,0,0,3,0,1,3,-7.830905584637071,88677
#
# Starting optimization iteration 45
# Loss computed by CAFQA VQE is -7.830905584637071, in 0.01647794060409069 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,2,2,0,2,0,0,0,0,0,0,0,2,2,2,3,-7.830905584637071,90922
#
# Starting optimization iteration 46
# Loss computed by CAFQA VQE is -7.830905584637071, in 0.014678418636322021 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,2,2,0,0,0,2,2,0,0,0,0,3,0,2,3,-7.830905584637071,93061
#
# Starting optimization iteration 47
# Loss computed by CAFQA VQE is -7.830905584637071, in 0.016644894145429134 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,2,2,0,0,1,2,3,0,0,0,0,3,0,1,3,-7.830905584637071,95251
#
# Starting optimization iteration 48
# Loss computed by CAFQA VQE is -7.767320185325607, in 0.017163054086267948 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,2,2,0,1,1,2,3,0,1,0,0,2,2,2,3,-7.767320185325607,97471
#
# Starting optimization iteration 49
# Loss computed by CAFQA VQE is -4.497540298478474, in 0.013689071871340275 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,2,3,2,0,0,3,0,3,0,3,0,1,2,0,3,-4.497540298478474,97566
#
# Starting optimization iteration 50
# Loss computed by CAFQA VQE is -7.663615545332058, in 0.016827893443405628 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,2,2,1,1,1,0,3,0,1,0,0,3,2,2,3,-7.663615545332058,99778
#
# Starting optimization iteration 51
# Loss computed by CAFQA VQE is -7.767320141889044, in 0.014653981663286686 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,2,2,3,3,0,1,2,0,0,0,0,0,0,2,0,-7.767320141889044,101943
#
# Starting optimization iteration 52
# Loss computed by CAFQA VQE is -3.18210093819084, in 0.016054248437285423 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 2,1,0,3,3,1,1,3,0,3,2,3,1,1,1,1,-3.18210093819084,102040
#
# Starting optimization iteration 53
# Loss computed by CAFQA VQE is -7.2142941702508505, in 0.015652873553335667 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,2,2,2,2,1,1,1,0,2,0,0,1,0,2,0,-7.2142941702508505,104233
#
# Starting optimization iteration 54
# Loss computed by CAFQA VQE is -4.103156838105281, in 0.014543889090418816 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,2,1,1,0,3,0,1,1,0,3,1,3,1,2,0,-4.103156838105281,104331
#
# Starting optimization iteration 55
# Loss computed by CAFQA VQE is -7.703734742577578, in 0.01647681649774313 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,2,2,0,1,0,2,2,0,2,0,0,3,0,1,3,-7.703734742577578,106565
#
# Starting optimization iteration 56
# Loss computed by CAFQA VQE is -6.799063117591624, in 0.014243743382394314 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,2,3,0,1,0,0,2,0,0,0,0,0,1,0,3,-6.799063117591624,108793
#
# Starting optimization iteration 57
# Loss computed by CAFQA VQE is -7.830905584637071, in 0.016822216100990772 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,2,2,0,2,0,3,3,0,0,0,0,2,2,1,0,-7.830905584637071,110985
#
# Starting optimization iteration 58
# Loss computed by CAFQA VQE is -7.830905584637071, in 0.015000198036432266 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,2,2,0,3,0,1,3,0,0,0,0,2,3,2,3,-7.830905584637071,113192
#
# Starting optimization iteration 59
# Loss computed by CAFQA VQE is -5.00732447120926, in 0.014802252873778343 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,3,0,0,3,2,2,0,3,1,1,0,3,1,1,1,-5.00732447120926,113290
#
# Starting optimization iteration 60
# Loss computed by CAFQA VQE is -7.830905584637071, in 0.014371052384376526 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,2,2,0,0,0,2,0,0,0,0,0,3,2,1,2,-7.830905584637071,115511
#
# Starting optimization iteration 61
# Loss computed by CAFQA VQE is -6.364714009371197, in 0.014552110806107521 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 1,2,1,1,3,0,0,0,0,1,3,2,0,0,3,2,-6.364714009371197,115610
#
# Starting optimization iteration 62
# Loss computed by CAFQA VQE is -5.33571822734472, in 0.022051211446523666 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,2,0,1,2,0,1,1,0,0,0,0,0,2,2,3,-5.33571822734472,117820
#
# Starting optimization iteration 63
# Loss computed by CAFQA VQE is -6.303975273360422, in 0.01681648287922144 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,3,2,0,0,0,3,2,0,2,0,0,2,0,1,3,-6.303975273360422,120037
#
# Starting optimization iteration 64
# Loss computed by CAFQA VQE is -7.767320163607325, in 0.015377530828118324 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,2,2,3,1,2,1,0,0,0,0,0,2,0,2,3,-7.767320163607325,122246
#
# Starting optimization iteration 65
# Loss computed by CAFQA VQE is -7.703734742577578, in 0.015897206030786037 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,2,2,0,2,0,1,2,0,2,0,0,2,2,2,3,-7.703734742577578,124483
#
# Starting optimization iteration 66
# Loss computed by CAFQA VQE is -7.767320141889044, in 0.01654713600873947 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,2,2,2,1,2,0,3,0,0,0,1,2,0,0,2,-7.767320141889044,126673
#
# Starting optimization iteration 67
# Loss computed by CAFQA VQE is -7.830905584637071, in 0.015168906189501286 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,2,2,0,0,3,1,1,0,0,0,0,3,2,2,2,-7.830905584637071,128858
#
# Starting optimization iteration 68
# Loss computed by CAFQA VQE is -7.703734742577578, in 0.015775111503899097 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,2,2,0,3,0,2,1,0,2,0,0,2,1,1,2,-7.703734742577578,131011
#
# Starting optimization iteration 69
# Loss computed by CAFQA VQE is -2.714448182419245, in 0.014430874958634377 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 3,0,0,2,0,3,0,0,1,1,2,1,1,3,0,1,-2.714448182419245,131111
#
# Starting optimization iteration 70
# Loss computed by CAFQA VQE is -6.2146741033586785, in 0.028186568059027195 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,3,2,2,1,2,0,0,0,0,0,2,1,2,2,2,-6.2146741033586785,133322
#
# Starting optimization iteration 71
# Loss computed by CAFQA VQE is -6.397317816933143, in 0.015188458375632763 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 2,1,2,3,3,1,0,3,2,0,0,3,2,3,1,0,-6.397317816933143,133430
#
# Starting optimization iteration 72
# Loss computed by CAFQA VQE is -6.242914818234874, in 0.016511574387550354 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,2,2,0,0,3,3,1,0,1,3,0,3,0,0,0,-6.242914818234874,135612
#
# Starting optimization iteration 73
# Loss computed by CAFQA VQE is -7.767320163607325, in 0.016018218360841274 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,2,2,3,3,0,2,0,0,0,0,0,0,3,2,1,-7.767320163607325,137862
#
# Starting optimization iteration 74
# Loss computed by CAFQA VQE is -7.767320163607325, in 0.01612013392150402 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,2,2,0,0,2,0,0,0,0,0,1,2,0,3,3,-7.767320163607325,140092
#
# Starting optimization iteration 75
# Loss computed by CAFQA VQE is -7.767320163607325, in 0.017339604906737804 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 2,2,0,1,0,3,3,3,2,2,2,2,0,1,1,2,-7.767320163607325,142215
#
# Starting optimization iteration 76
# Loss computed by CAFQA VQE is -4.555457858310481, in 0.013372871093451977 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 1,1,2,0,0,3,0,1,0,1,0,0,3,0,2,2,-4.555457858310481,142311
#
# Starting optimization iteration 77
# Loss computed by CAFQA VQE is -7.767320141889044, in 0.017666644416749477 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 2,2,0,1,0,3,0,3,2,2,2,3,0,3,0,3,-7.767320141889044,144509
#
# Starting optimization iteration 78
# Loss computed by CAFQA VQE is -6.551519206335165, in 0.018250009045004845 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 2,2,3,0,0,3,0,3,2,2,3,2,0,2,3,2,-6.551519206335165,146701
#
# Starting optimization iteration 79
# Loss computed by CAFQA VQE is -5.17245872783362, in 0.016910805366933346 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 3,2,0,0,0,3,2,3,2,2,1,3,0,3,0,1,-5.17245872783362,148880
#
# Starting optimization iteration 80
# Loss computed by CAFQA VQE is -6.421835622102284, in 0.01911714393645525 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 3,2,0,1,0,3,1,3,3,2,2,3,0,3,1,2,-6.421835622102284,151117
#
# Starting optimization iteration 81
# Loss computed by CAFQA VQE is -7.830905584637071, in 0.015242715366184711 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,2,2,0,0,3,2,2,0,0,0,0,3,2,1,1,-7.830905584637071,153331
#
# Starting optimization iteration 82
# Loss computed by CAFQA VQE is -2.0552249938816316, in 0.014636731706559658 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 2,2,2,0,3,2,3,3,0,2,3,0,3,2,0,3,-2.0552249938816316,153440
#
# Starting optimization iteration 83
# Loss computed by CAFQA VQE is -6.430737673093924, in 0.017707963474094868 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 2,3,0,2,0,3,3,1,2,2,2,3,0,1,1,3,-6.430737673093924,155595
#
# Starting optimization iteration 84
# Loss computed by CAFQA VQE is -4.83509836024093, in 0.015075727365911007 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,1,0,1,0,2,3,0,1,2,1,2,1,1,3,1,-4.83509836024093,155703
#
# Starting optimization iteration 85
# Loss computed by CAFQA VQE is -7.767320185325608, in 0.017331372946500778 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 2,2,0,2,0,3,2,3,2,2,2,1,0,0,1,2,-7.767320185325608,157948
#
# Starting optimization iteration 86
# Loss computed by CAFQA VQE is -6.430834722986576, in 0.016017692163586617 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,1,2,2,3,0,1,3,0,0,0,1,0,1,0,3,-6.430834722986576,160148
#
# Starting optimization iteration 87
# Loss computed by CAFQA VQE is -7.647701741258851, in 0.016021189279854298 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,2,2,1,3,1,1,2,0,1,0,0,0,3,3,0,-7.647701741258851,162368
#
# Starting optimization iteration 88
# Loss computed by CAFQA VQE is -7.767320163607325, in 0.01444226410239935 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,2,2,3,0,3,3,0,0,0,0,0,0,0,1,1,-7.767320163607325,164589
#
# Starting optimization iteration 89
# Loss computed by CAFQA VQE is -6.432167948829889, in 0.016149114817380905 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 2,1,0,2,3,0,2,3,2,2,2,1,0,0,0,2,-6.432167948829889,166791
#
# Starting optimization iteration 90
# Loss computed by CAFQA VQE is -6.367560694390168, in 0.016177772544324398 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,2,2,0,1,1,1,1,1,0,0,0,2,2,2,3,-6.367560694390168,169023
#
# Starting optimization iteration 91
# Loss computed by CAFQA VQE is -7.647701741258851, in 0.016426307149231434 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 2,2,0,1,0,3,0,3,2,1,2,3,0,1,0,1,-7.647701741258851,171184
#
# Starting optimization iteration 92
# Loss computed by CAFQA VQE is -5.094252232473175, in 0.014310689643025398 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 2,0,0,1,0,3,0,0,2,2,2,0,0,0,0,1,-5.094252232473175,173388
#
# Starting optimization iteration 93
# Loss computed by CAFQA VQE is -6.25932468835955, in 0.017635788768529892 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 2,2,0,1,0,3,1,3,1,2,2,1,0,1,1,2,-6.25932468835955,175570
#
# Starting optimization iteration 94
# Loss computed by CAFQA VQE is -7.528083297192095, in 0.01639486663043499 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 2,2,0,1,0,2,2,3,2,0,2,3,0,2,0,1,-7.528083297192095,177884
#
# Starting optimization iteration 95
# Loss computed by CAFQA VQE is -7.830905584637071, in 0.016622559167444706 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 2,2,0,1,0,0,2,2,2,2,2,1,0,0,1,2,-7.830905584637071,180107
#
# Starting optimization iteration 96
# Loss computed by CAFQA VQE is -7.767320185325608, in 0.015836496837437153 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 2,2,0,0,0,1,2,3,2,2,2,1,0,0,0,0,-7.767320185325608,182355
#
# Starting optimization iteration 97
# Loss computed by CAFQA VQE is -7.767320185325608, in 0.015227975323796272 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 2,2,0,0,0,0,2,1,2,2,2,1,0,0,1,0,-7.767320185325608,184593
#
# Starting optimization iteration 98
# Loss computed by CAFQA VQE is -7.767320141889044, in 0.01719288993626833 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,2,2,3,0,1,3,3,0,0,0,2,3,1,1,3,-7.767320141889044,186872
#
# Starting optimization iteration 99
# Loss computed by CAFQA VQE is -6.431900762268407, in 0.015697788447141647 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 2,3,0,1,0,0,3,2,2,0,2,2,0,0,1,2,-6.431900762268407,189091
#
# Starting optimization iteration 100
# Loss computed by CAFQA VQE is -6.283311551667818, in 0.013154487125575542 s.
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value,Timestamp
# 0,2,3,3,1,0,1,3,0,2,0,1,0,0,2,0,-6.283311551667818,189202
#
# End of Bayesian Optimization
# Minimum of the posterior mean:
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value
# 0,2,2,0,0,1,2,2,0,0,0,0,3,2,1,3,-7.830905584637071
#
# Best point found:
# x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14,x15,value
# 0,2,2,0,2,0,1,3,0,0,0,0,3,2,2,3,-7.830905584637071
#
# End of HyperMapper
